# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import lasio

# %% [markdown]
# # Read log data from a las file and then convert it to a df

# %%
las_file = lasio.read("15_9-13.las")
las_file.curves
# Out:
# [CurveItem(mnemonic="DEPT", unit="m", value="", descr="DEPTH", original_mnemonic="DEPT", data.shape=(21441,)),
#  CurveItem(mnemonic="FORCE_2020_LITHOFACIES_CONFIDENCE", unit="_", value="", descr="FORCE_2020_LITHOFACIES_CONFIDENCE", original_mnemonic="FORCE_2020_LITHOFACIES_CONFIDENCE", data.shape=(21441,)),
#  CurveItem(mnemonic="FORCE_2020_LITHOFACIES_LITHOLOGY", unit="_", value="", descr="FORCE_2020_LITHOFACIES_LITHOLOGY", original_mnemonic="FORCE_2020_LITHOFACIES_LITHOLOGY", data.shape=(21441,)),
#  CurveItem(mnemonic="CALI", unit="in", value="", descr="CALI", original_mnemonic="CALI", data.shape=(21441,)),
#  CurveItem(mnemonic="MUDWEIGHT", unit="_", value="", descr="MUDWEIGHT", original_mnemonic="MUDWEIGHT", data.shape=(21441,)),
#  CurveItem(mnemonic="ROP", unit="m/h", value="", descr="ROP", original_mnemonic="ROP", data.shape=(21441,)),
#  CurveItem(mnemonic="RDEP", unit="ohm.m", value="", descr="RDEP", original_mnemonic="RDEP", data.shape=(21441,)),
#  CurveItem(mnemonic="RSHA", unit="ohm.m", value="", descr="RSHA", original_mnemonic="RSHA", data.shape=(21441,)),
#  CurveItem(mnemonic="RMED", unit="ohm.m", value="", descr="RMED", original_mnemonic="RMED", data.shape=(21441,)),
#  CurveItem(mnemonic="RXO", unit="ohm.m", value="", descr="RXO", original_mnemonic="RXO", data.shape=(21441,)),
#  CurveItem(mnemonic="SP", unit="mV", value="", descr="SP", original_mnemonic="SP", data.shape=(21441,)),
#  CurveItem(mnemonic="DTC", unit="us/ft", value="", descr="DTC", original_mnemonic="DTC", data.shape=(21441,)),
#  CurveItem(mnemonic="NPHI", unit="m3/m3", value="", descr="NPHI", original_mnemonic="NPHI", data.shape=(21441,)),
#  CurveItem(mnemonic="PEF", unit="b/e", value="", descr="PEF", original_mnemonic="PEF", data.shape=(21441,)),
#  CurveItem(mnemonic="GR", unit="gAPI", value="", descr="GR", original_mnemonic="GR", data.shape=(21441,)),
#  CurveItem(mnemonic="RHOB", unit="g/cm3", value="", descr="RHOB", original_mnemonic="RHOB", data.shape=(21441,)),
#  CurveItem(mnemonic="DRHO", unit="g/cm3", value="", descr="DRHO", original_mnemonic="DRHO", data.shape=(21441,)),
#  CurveItem(mnemonic="DEPTH_MD", unit="_", value="", descr="DEPTH_MD", original_mnemonic="DEPTH_MD", data.shape=(21441,)),
#  CurveItem(mnemonic="X_LOC", unit="_", value="", descr="x_loc", original_mnemonic="X_LOC", data.shape=(21441,)),
#  CurveItem(mnemonic="Y_LOC", unit="_", value="", descr="y_loc", original_mnemonic="Y_LOC", data.shape=(21441,)),
#  CurveItem(mnemonic="Z_LOC", unit="_", value="", descr="z_loc", original_mnemonic="Z_LOC", data.shape=(21441,))]

# %%
# store the las_file in a data frame variable
df_las = las_file.df()

# %%
df_las
# Out:
#           FORCE_2020_LITHOFACIES_CONFIDENCE  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# DEPT
# 25.000                                  NaN                               NaN
# 25.152                                  NaN                               NaN
# 25.304                                  NaN                               NaN
# 25.456                                  NaN                               NaN
# 25.608                                  NaN                               NaN
# ...                                     ...                               ...
# 3283.272                                NaN                               NaN
# 3283.424                                NaN                               NaN
# 3283.576                                NaN                               NaN
# 3283.728                                NaN                               NaN
# 3283.880                                NaN                               NaN
#
#           CALI  MUDWEIGHT  ROP  RDEP  RSHA    RMED  RXO          SP  \
# DEPT
# 25.000     NaN        NaN  NaN   NaN   NaN     NaN  NaN         NaN
# 25.152     NaN        NaN  NaN   NaN   NaN     NaN  NaN         NaN
# 25.304     NaN        NaN  NaN   NaN   NaN     NaN  NaN         NaN
# 25.456     NaN        NaN  NaN   NaN   NaN     NaN  NaN         NaN
# 25.608     NaN        NaN  NaN   NaN   NaN     NaN  NaN         NaN
# ...        ...        ...  ...   ...   ...     ...  ...         ...
# 3283.272   NaN        NaN  NaN   8.0   NaN  7.9922  NaN  152.693741
# 3283.424   NaN        NaN  NaN   8.0   NaN  7.9922  NaN  152.759003
# 3283.576   NaN        NaN  NaN   8.0   NaN  7.9922  NaN  151.934555
# 3283.728   NaN        NaN  NaN   8.0   NaN  7.9922  NaN  151.542679
# 3283.880   NaN        NaN  NaN   8.0   NaN  7.9922  NaN  151.691086
#
#                  DTC  NPHI  PEF  GR  RHOB  DRHO     DEPTH_MD     X_LOC  \
# DEPT
# 25.000    206.224609   NaN  NaN NaN   NaN   NaN          NaN       NaN
# 25.152    206.224625   NaN  NaN NaN   NaN   NaN          NaN       NaN
# 25.304    206.224655   NaN  NaN NaN   NaN   NaN          NaN       NaN
# 25.456    206.224670   NaN  NaN NaN   NaN   NaN          NaN       NaN
# 25.608    206.224701   NaN  NaN NaN   NaN   NaN          NaN       NaN
# ...              ...   ...  ...  ..   ...   ...          ...       ...
# 3283.272         NaN   NaN  NaN NaN   NaN   NaN  3283.271973  437593.0
# 3283.424         NaN   NaN  NaN NaN   NaN   NaN  3283.424072  437593.0
# 3283.576         NaN   NaN  NaN NaN   NaN   NaN  3283.575928  437593.0
# 3283.728         NaN   NaN  NaN NaN   NaN   NaN  3283.728027  437593.0
# 3283.880         NaN   NaN  NaN NaN   NaN   NaN  3283.879883  437593.0
#
#               Y_LOC        Z_LOC
# DEPT
# 25.000          NaN          NaN
# 25.152          NaN          NaN
# 25.304          NaN          NaN
# 25.456          NaN          NaN
# 25.608          NaN          NaN
# ...             ...          ...
# 3283.272  6470982.5 -3257.389893
# 3283.424  6470982.5 -3257.541992
# 3283.576  6470982.5 -3257.693848
# 3283.728  6470982.5 -3257.845703
# 3283.880  6470982.5 -3257.997803
#
# [21441 rows x 20 columns]

# %%
df_las.head()
# Out:
#         FORCE_2020_LITHOFACIES_CONFIDENCE  FORCE_2020_LITHOFACIES_LITHOLOGY  \
# DEPT
# 25.000                                NaN                               NaN
# 25.152                                NaN                               NaN
# 25.304                                NaN                               NaN
# 25.456                                NaN                               NaN
# 25.608                                NaN                               NaN
#
#         CALI  MUDWEIGHT  ROP  RDEP  RSHA  RMED  RXO  SP         DTC  NPHI  \
# DEPT
# 25.000   NaN        NaN  NaN   NaN   NaN   NaN  NaN NaN  206.224609   NaN
# 25.152   NaN        NaN  NaN   NaN   NaN   NaN  NaN NaN  206.224625   NaN
# 25.304   NaN        NaN  NaN   NaN   NaN   NaN  NaN NaN  206.224655   NaN
# 25.456   NaN        NaN  NaN   NaN   NaN   NaN  NaN NaN  206.224670   NaN
# 25.608   NaN        NaN  NaN   NaN   NaN   NaN  NaN NaN  206.224701   NaN
#
#         PEF  GR  RHOB  DRHO  DEPTH_MD  X_LOC  Y_LOC  Z_LOC
# DEPT
# 25.000  NaN NaN   NaN   NaN       NaN    NaN    NaN    NaN
# 25.152  NaN NaN   NaN   NaN       NaN    NaN    NaN    NaN
# 25.304  NaN NaN   NaN   NaN       NaN    NaN    NaN    NaN
# 25.456  NaN NaN   NaN   NaN       NaN    NaN    NaN    NaN
# 25.608  NaN NaN   NaN   NaN       NaN    NaN    NaN    NaN

# %%
df_las.shape
# Out:
# (21441, 20)

# %%
#this will check the available log in the dataset
df_las.columns
# Out:
# Index(['FORCE_2020_LITHOFACIES_CONFIDENCE', 'FORCE_2020_LITHOFACIES_LITHOLOGY',
#        'CALI', 'MUDWEIGHT', 'ROP', 'RDEP', 'RSHA', 'RMED', 'RXO', 'SP', 'DTC',
#        'NPHI', 'PEF', 'GR', 'RHOB', 'DRHO', 'DEPTH_MD', 'X_LOC', 'Y_LOC',
#        'Z_LOC'],
#       dtype='object')

# %%
df_las_selected = df_las[["RDEP", "RSHA", "RMED", "GR", "NPHI", "RHOB"]]

# %%
df_las_selected.isna()
# Out:
#            RDEP  RSHA   RMED    GR  NPHI  RHOB
# DEPT
# 25.000     True  True   True  True  True  True
# 25.152     True  True   True  True  True  True
# 25.304     True  True   True  True  True  True
# 25.456     True  True   True  True  True  True
# 25.608     True  True   True  True  True  True
# ...         ...   ...    ...   ...   ...   ...
# 3283.272  False  True  False  True  True  True
# 3283.424  False  True  False  True  True  True
# 3283.576  False  True  False  True  True  True
# 3283.728  False  True  False  True  True  True
# 3283.880  False  True  False  True  True  True
#
# [21441 rows x 6 columns]

# %%
df_las_selected.isna().sum()
# Out:
# RDEP      485
# RSHA    19818
# RMED      484
# GR        541
# NPHI     7336
# RHOB     3096
# dtype: int64

# %%
df_las_data_dropped = df_las_selected.dropna(subset=["RDEP", "RSHA", "RMED", "GR", "NPHI", "RHOB"], axis=0, how="any")

# %%
df_las_data_dropped
# Out:
#               RDEP      RSHA      RMED         GR      NPHI      RHOB
# DEPT
# 2360.024  0.793339  0.297633  0.623069  39.730061  0.583409  2.027478
# 2360.176  0.776576  0.269429  0.627331  43.091839  0.582297  1.961962
# 2360.328  0.751839  0.289620  0.647835  43.753174  0.573836  1.868283
# 2360.480  0.712272  0.326678  0.664831  42.127659  0.556636  1.835587
# 2360.632  0.686251  0.352923  0.681010  38.995285  0.523758  1.869930
# ...            ...       ...       ...        ...       ...       ...
# 2849.160  1.996534  1.126376  2.195300  93.427177  0.353096  2.503552
# 2849.312  2.020279  1.151722  2.093063  93.428482  0.351230  2.475946
# 2849.464  2.002983  1.207337  2.089704  89.935890  0.335432  2.452285
# 2849.616  2.002000  1.260124  1.975173  88.565834  0.329863  2.422112
# 2849.768  2.009372  1.135126  2.038925  92.930046  0.320338  2.425509
#
# [1623 rows x 6 columns]

# %%
df_las_data_dropped.describe()
# Out:
#               RDEP         RSHA         RMED           GR         NPHI  \
# count  1623.000000  1623.000000  1623.000000  1623.000000  1623.000000
# mean      3.985709     2.901504     3.681225    62.467078     0.311638
# std       4.701107     3.474120     3.659987    54.835510     0.134473
# min       0.538233     0.175400     0.435928     6.651642     0.058346
# 25%       1.701318     0.934778     1.860777    30.917796     0.221690
# 50%       2.140086     1.473143     2.339364    42.450695     0.298457
# 75%       5.331349     3.352066     4.958984    84.891869     0.381191
# max      49.221905    54.536583    34.411457   499.022583     0.731645
#
#               RHOB
# count  1623.000000
# mean      2.289887
# std       0.245285
# min       1.493417
# 25%       2.160696
# 50%       2.308868
# 75%       2.495180
# max       2.889454

# %%
#filter data 
df_filter = df_las_data_dropped.loc[(df_las_data_dropped.GR > 0) & (df_las_data_dropped.GR <= 250)]
df_filter1 = df_filter.loc[(df_filter.RHOB >= 1) & (df_filter.RHOB <= 3)]

# %%
#calculate the shale volume
#make a copy of the filtered data
df = df_filter1.copy()
df["VSH"] = (df.GR - df.GR.min()) / (df.GR.max() - df.GR.min())

# %%
df.head(2)
# Out:
#               RDEP      RSHA      RMED         GR      NPHI      RHOB  \
# DEPT
# 2360.024  0.793339  0.297633  0.623069  39.730061  0.583409  2.027478
# 2360.176  0.776576  0.269429  0.627331  43.091839  0.582297  1.961962
#
#                vsh
# DEPT
# 2360.024  0.139377
# 2360.176  0.153542

# %%
#rename index
df_idx = df.rename_axis("DEPTH").reset_index()

# %%
df_idx.head(2)
# Out:
#       DEPTH      RDEP      RSHA      RMED         GR      NPHI      RHOB  \
# 0  2360.024  0.793339  0.297633  0.623069  39.730061  0.583409  2.027478
# 1  2360.176  0.776576  0.269429  0.627331  43.091839  0.582297  1.961962
#
#         vsh
# 0  0.139377
# 1  0.153542

# %%
#plotting with the help of matplotlib i will be writing a function for it
# "RDEP", "RSHA", "RMED", "GR", "NPHI", "RHOB"
def plot_logs(logs):
    logs.sort_values(by="DEPTH")
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    f, ax = plt.subplots(nrows = 1, ncols = 6, figsize=(12,8))
    ax[0].plot(logs.RDEP, logs.DEPTH, color="red")
    ax[1].plot(logs.RSHA, logs.DEPTH, color="green")
    ax[2].plot(logs.RMED, logs.DEPTH, color="yellow")
    ax[3].plot(logs.GR, logs.DEPTH, color="blue")
    ax[4].plot(logs.NPHI, logs.DEPTH, color="orange")
    ax[5].plot(logs.RHOB, logs.DEPTH, color="c")
    for i in range(len(ax)):
        ax[i].set_ylim(top, bot)
        ax[i].invert_yaxis()
        ax[i].grid()
    ax[0].set_xlabel("RDEP")
    ax[0].set_xlim(logs.RDEP.min(), logs.RDEP.max())
    ax[0].set_ylabel("Depth (ft)")
    ax[1].set_xlabel("RSHA")
    ax[1].set_xlim(logs.RSHA.min(), logs.RSHA.max())
    ax[2].set_xlabel("RMED")
    ax[2].set_xlim(logs.RMED.min(), logs.RMED.max())
    ax[3].set_xlabel("GR")
    ax[3].set_xlim(logs.GR.min(), logs.GR.max())
    ax[4].set_xlabel("NPHI")
    ax[4].set_xlim(logs.NPHI.min(), logs.NPHI.max())
    ax[5].set_xlabel("RHOB")
    ax[5].set_xlim(logs.RHOB.min(), logs.RHOB.max())

    ax[1].set_yticklabels([]);
    ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([]);
    ax[4].set_yticklabels([]);
    ax[5].set_yticklabels([]);

    f.suptitle("Well log analysis using python by Bello Hadi", fontsize=14, y=0.94)

# %%
plot_logs(df_idx)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plot_logs(df_idx)
#
# Cell In[41], line 38, in plot_logs(logs)
#      35 ax[4].set_yticklabels([]);
#      36 ax[5].set_yticklabels([]);
# ---> 38 f.subtitle("Well log analysis using python by Bello Hadi", fontsize=14, y=0.94)
#
# AttributeError: 'Figure' object has no attribute 'subtitle'
